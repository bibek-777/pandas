# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # creating a dataframe

# %%
pd.DataFrame(np.array([1,2,3,4,5]),index=list('abcde'),columns=list('g'))
# Out:
#    g
# a  1
# b  2
# c  3
# d  4
# e  5

# %%
a={'Ram':[1,2,3,4,5,6], 'Shyam':[7,8,9,10,11,12]}

# %%
a
# Out:
# {'Ram': [1, 2, 3, 4, 5, 6], 'Shyam': [7, 8, 9, 10, 11, 12]}

# %%
pd.DataFrame(a)
# Out:
#    Ram  Shyam
# 0    1      7
# 1    2      8
# 2    3      9
# 3    4     10
# 4    5     11
# 5    6     12

# %%
df = pd.read_csv('IPL_Matches.csv')
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
df.head(-5)
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 940   335991  Chandigarh  2008-04-25  2007/08           10
# 941   335990   Hyderabad  2008-04-24  2007/08            9
# 942   335989     Chennai  2008-04-23  2007/08            8
# 943   335988   Hyderabad  2008-04-22  2007/08            7
# 944   335987      Jaipur  2008-04-21  2007/08            6
#
#                            Team1                 Team2  \
# 0               Rajasthan Royals        Gujarat Titans
# 1    Royal Challengers Bangalore      Rajasthan Royals
# 2    Royal Challengers Bangalore  Lucknow Super Giants
# ...

# %% [markdown]
# # property of dataframe

# %%
df.size
# Out:
# 19000

# %%
df.shape
# Out:
# (950, 20)

# %%
df.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %% [markdown]
# # columns

# %%
len(df.columns)
# Out:
# 20

# %%
df.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df['ID']
# Out:
# 0      1312200
# 1      1312199
# 2      1312198
# 3      1312197
# 4      1304116
#         ...
# 945     335986
# 946     335985
# 947     335984
# 948     335983
# 949     335982
# Name: ID, Length: 950, dtype: int64

# %%
df[['ID','City']]
# Out:
#           ID        City
# 0    1312200   Ahmedabad
# 1    1312199   Ahmedabad
# 2    1312198     Kolkata
# 3    1312197     Kolkata
# 4    1304116      Mumbai
# ..       ...         ...
# 945   335986     Kolkata
# 946   335985      Mumbai
# 947   335984       Delhi
# 948   335983  Chandigarh
# 949   335982   Bangalore
#
# [950 rows x 2 columns]

# %%
df['Rakshya']=np.arange(1,951)

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# # rows

# %%
df.iloc[[678]]
# Out:
#          ID     City        Date Season MatchNumber                Team1  \
# 678  548330  Chennai  2012-04-19   2012          24  Chennai Super Kings
#
#              Team2                            Venue     TossWinner  \
# 678  Pune Warriors  MA Chidambaram Stadium, Chepauk  Pune Warriors
#
#     TossDecision  ...          WinningTeam WonBy Margin  method  \
# 678        field  ...  Chennai Super Kings  Runs   13.0     NaN
#
#      Player_of_Match                                       Team1Players  \
# 678  KMDN Kulasekara  ['F du Plessis', 'S Badrinath', 'SK Raina', 'M...
#
#                                           Team2Players    Umpire1 Umpire2  \
# 678  ['RV Uthappa', 'JD Ryder', 'SC Ganguly', 'MK P...  Asad Rauf   S Das
#
#     Rakshya
# 678     679
#
# [1 rows x 21 columns]

# %%
df.describe()
# Out:
#                  ID      Margin     Rakshya
# count  9.500000e+02  932.000000  950.000000
# mean   8.304852e+05   17.056867  475.500000
# std    3.375678e+05   21.633109  274.385677
# min    3.359820e+05    1.000000    1.000000
# 25%    5.012612e+05    6.000000  238.250000
# 50%    8.297380e+05    8.000000  475.500000
# 75%    1.175372e+06   19.000000  712.750000
# max    1.312200e+06  146.000000  950.000000

# %% [markdown]
# # data filter

# %%
df=pd.read_csv('titanic_test.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df.Age>20]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan, 'Qv'], dtype=object)

# %%
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.Age.count()
# Out:
# 714

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.Age.sum()
# Out:
# 21205.17

# %%
df.Age.isnull().sum()
# Out:
# 177

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['PassengerId']=df['PassengerId'].astype('int8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int8
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), int8(1), object(5)
# memory usage: 77.6+ KB

# %%
df.Age.isna().sum()
# Out:
# 177

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('Name', axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          119         0       2    male  27.0      0      0
# 887          120         1       1  female  19.0      0      0
# 888          121         0       3  female   NaN      1      2
# 889          122         1       1    male  26.0      0      0
# 890          123         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.drop(['Cabin','Pclass'], axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived     Sex   Age  SibSp  Parch            Ticket  \
# 0              1         0    male  22.0      1      0         A/5 21171
# 1              2         1  female  38.0      1      0          PC 17599
# 2              3         1  female  26.0      0      0  STON/O2. 3101282
# 3              4         1  female  35.0      1      0            113803
# 4              5         0    male  35.0      0      0            373450
# ..           ...       ...     ...   ...    ...    ...               ...
# 886          119         0    male  27.0      0      0            211536
# 887          120         1  female  19.0      0      0            112053
# 888          121         0  female   NaN      1      2        W./C. 6607
# 889          122         1    male  26.0      0      0            111369
# 890          123         0    male  32.0      0      0            370376
#
#         Fare Embarked
# 0     7.2500        S
# 1    71.2833        C
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int8
#  1   Survived     891 non-null    int64
#  2   Sex          891 non-null    object
#  3   Age          714 non-null    float64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
#  6   Ticket       891 non-null    object
#  7   Fare         891 non-null    float64
#  8   Embarked     889 non-null    object
# dtypes: float64(2), int64(3), int8(1), object(3)
# memory usage: 56.7+ KB

# %%
df.Age.isna().sum()
# Out:
# 177

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
round(df.Age.mean())
# Out:
# 30

# %%
df.Age.median()
# Out:
# 28.0

# %%
(20000+30000+22000+6000000)/4
# Out:
# 1518000.0

# %%
df.fillna(df.Age.mean(), inplace=True)

# %%
df.Age.isna().sum()
# Out:
# 0

# %%
df.Embarked.mode().sum()
# Out:
# 'S'

# %%
df.head()
# Out:
#    PassengerId  Survived     Sex   Age  SibSp  Parch            Ticket  \
# 0            1         0    male  22.0      1      0         A/5 21171
# 1            2         1  female  38.0      1      0          PC 17599
# 2            3         1  female  26.0      0      0  STON/O2. 3101282
# 3            4         1  female  35.0      1      0            113803
# 4            5         0    male  35.0      0      0            373450
#
#       Fare Embarked
# 0   7.2500        S
# 1  71.2833        C
# 2   7.9250        S
# 3  53.1000        S
# 4   8.0500        S
